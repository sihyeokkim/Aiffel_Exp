# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#데이터준비" data-toc-modified-id="데이터준비-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>데이터준비</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#결측치,-중복데이터-제거" data-toc-modified-id="결측치,-중복데이터-제거-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>결측치, 중복데이터 제거</a></span></li><li><span><a href="#train_data/-test_dat-결측치-및-중복데이터-제거-완료" data-toc-modified-id="train_data/-test_dat-결측치-및-중복데이터-제거-완료-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>train_data/ test_dat 결측치 및 중복데이터 제거 완료</a></span></li><li><span><a href="#tokenizing" data-toc-modified-id="tokenizing-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>tokenizing</a></span></li><li><span><a href="#encoder-&amp;-decoder" data-toc-modified-id="encoder-&amp;-decoder-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>encoder &amp; decoder</a></span></li><li><span><a href="#pad_sequences를-통해-문장의-길이를-통일" data-toc-modified-id="pad_sequences를-통해-문장의-길이를-통일-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>pad_sequences를 통해 문장의 길이를 통일</a></span></li><li><span><a href="#validation-set-구성" data-toc-modified-id="validation-set-구성-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>validation set 구성</a></span></li></ul></li></ul></li><li><span><a href="#Apply-to-models" data-toc-modified-id="Apply-to-models-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Apply to models</a></span><ul class="toc-item"><li><span><a href="#LSTM-모델설계" data-toc-modified-id="LSTM-모델설계-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>LSTM 모델설계</a></span><ul class="toc-item"><li><span><a href="#LSTM-학습" data-toc-modified-id="LSTM-학습-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>LSTM 학습</a></span></li><li><span><a href="#네이버-영화리뷰-데이터-감성분석-정확도" data-toc-modified-id="네이버-영화리뷰-데이터-감성분석-정확도-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>네이버 영화리뷰 데이터 감성분석 정확도</a></span></li><li><span><a href="#시각화" data-toc-modified-id="시각화-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>시각화</a></span></li><li><span><a href="#Embedding-layer-분석" data-toc-modified-id="Embedding-layer-분석-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Embedding layer 분석</a></span></li></ul></li><li><span><a href="#한국어-Word2Vec-임베딩-활용하여-성능-개선" data-toc-modified-id="한국어-Word2Vec-임베딩-활용하여-성능-개선-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>한국어 Word2Vec 임베딩 활용하여 성능 개선</a></span><ul class="toc-item"><li><span><a href="#전-모델의-임베딩-레이어를-Word2Vec(word_vectors)의-것으로-교체하여-설계" data-toc-modified-id="전-모델의-임베딩-레이어를-Word2Vec(word_vectors)의-것으로-교체하여-설계-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>전 모델의 임베딩 레이어를 Word2Vec(word_vectors)의 것으로 교체하여 설계</a></span></li><li><span><a href="#Word2Vec학습" data-toc-modified-id="Word2Vec학습-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Word2Vec학습</a></span></li><li><span><a href="#Word2Vec(word_vectors)-정확도" data-toc-modified-id="Word2Vec(word_vectors)-정확도-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Word2Vec(word_vectors) 정확도</a></span></li><li><span><a href="#Word2Vec(word_vectors)-시각화" data-toc-modified-id="Word2Vec(word_vectors)-시각화-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Word2Vec(word_vectors) 시각화</a></span></li></ul></li><li><span><a href="#GlobalMaxPooling" data-toc-modified-id="GlobalMaxPooling-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>GlobalMaxPooling</a></span><ul class="toc-item"><li><span><a href="#GMP설계" data-toc-modified-id="GMP설계-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>GMP설계</a></span></li><li><span><a href="#GMP학습" data-toc-modified-id="GMP학습-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>GMP학습</a></span></li><li><span><a href="#GMP정확도" data-toc-modified-id="GMP정확도-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>GMP정확도</a></span></li><li><span><a href="#GMP시각화" data-toc-modified-id="GMP시각화-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>GMP시각화</a></span></li></ul></li></ul></li><li><span><a href="#회고" data-toc-modified-id="회고-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>회고</a></span></li></ul></div>

# %%
import os
import re
import pandas as pd
import numpy as np

import urllib.request
import matplotlib.pyplot as plt
# %matplotlib inline


from konlpy.tag import Okt
from konlpy.tag import Mecab

from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.initializers import Constant
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

from collections import Counter
import gensim
from gensim.models import KeyedVectors
from gensim.models.keyedvectors import Word2VecKeyedVectors

# %% [markdown]
# # 데이터준비

# %%
# 데이터load 
train_data_origin = pd.read_table('~/aiffel/sentiment_classification/data/ratings_train.txt')
test_data_origin = pd.read_table('~/aiffel/sentiment_classification/data/ratings_test.txt')

train_data_origin.info()
test_data_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        50000 non-null  int64
#  1   document  49997 non-null  object
#  2   label     50000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 결측치, 중복데이터 제거

# %%
train_data_origin[train_data_origin.document.isnull()]
# Out:
#              id document  label
# 25857   2172111      NaN      1
# 55737   6369843      NaN      1
# 110014  1034280      NaN      0
# 126782  5942978      NaN      0
# 140721  1034283      NaN      0

# %%
test_data_origin[test_data_origin.document.isnull()]
# Out:
#             id document  label
# 5746    402110      NaN      1
# 7899   5026896      NaN      0
# 27097   511097      NaN      1

# %%
train_data_origin[train_data_origin.duplicated(subset='document', keep= 'first')]
# Out:
#              id document  label
# 1058    5890638        4      0
# 1097    2062443       쵝오      1
# 1248    3502685       최고      1
# 1483     775332       최고      1
# 1707    8009134      재밌다      1
# ...         ...      ...    ...
# 149919  6502490        짱      1
# 149949  3924716    OO 영화      0
# 149960  6368431     지루하다      0
# 149966  6735753        1      0
# 149987  7669621  재미있어요^^      1
#
# [3817 rows x 3 columns]

# %%
test_data_origin[test_data_origin.duplicated(subset='document', keep= 'first')]
# Out:
#             id                  document  label
# 857    2084375                       bad      0
# 956     195683                     재미있어요      1
# 1089   2235528                       볼만함      1
# 1149   4409686                         굿      1
# 1600   3805716                        최고      1
# ...        ...                       ...    ...
# 49731  7437033                        별로      0
# 49760  5890883                      최악이다      0
# 49767  4032953                        최고      1
# 49841  8097768  2년이 지나도 잊혀지지 않는 소중한 드라마.      1
# 49934  6929887                         굿      1
#
# [842 rows x 3 columns]

# %%
def del_null_dupl(data):
    data=data.dropna(axis=0)
    data=data[~data.duplicated(subset='document', keep= 'first')]
    data=data.reset_index(drop=True)# index reset하기 - 기존 index 제거 O
    return data

train_data=del_null_dupl(train_data_origin)
test_data=del_null_dupl(test_data_origin)

# %%
train_data.isnull().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %%
train_data[train_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, document, label]
# Index: []

# %%
test_data[test_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, document, label]
# Index: []

# %% [markdown]
# ### train_data/ test_dat 결측치 및 중복데이터 제거 완료

# %% [markdown]
# ### tokenizing

# %%
tokenizer = Mecab() #형태소(가장작은 말의 단위)분석기
# 하늘은 스스로 돕는 자를 돕는다. → 하늘, 은, 스스로, 돕-, -는, 자, 를, 돕-, -는-, -다.
tokenizer.pos("이것은 메캅테스트입니다. 사용자 사전을 등록하기 전입니다. 비타500")
# 텍스트에서 품사 정보를 부착하여 반환한다(대명사, 형용사, 명사 등등)
# Out:
# [('이것', 'NP'),
#  ('은', 'JX'),
#  ('메', 'NNP'),
#  ('캅', 'NNP'),
#  ('테스트', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('사용자', 'NNG'),
#  ('사전', 'NNG'),
#  ('을', 'JKO'),
#  ('등록', 'NNG'),
#  ('하', 'XSV'),
#  ('기', 'ETN'),
#  ('전', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('비타', 'NNP'),
#  ('500', 'SN')]

# %%
train_data['document'].shape
# Out:
# (146182,)

# %%
train_data['document'][0] #각 행마다 한문장씩 들어 있음을 확인
# Out:
# '아 더빙.. 진짜 짜증나네요 목소리'

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

def load_data(train_data, test_data, num_words=10000):

    X_train = []
    for sentence in train_data['document']: # 146182 번 반복
        global temp_X
        temp_X = tokenizer.morphs(sentence) # 토큰화, morphs( text ) 텍스트에서 형태소를 반환.
        # sentence: '아 더빙.. 진짜 짜증나네요 목소리' 의 형태소를 temp_X에 저장

        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_train.append(temp_X)

    X_test = []
    for sentence in test_data['document']:
        temp_X = tokenizer.morphs(sentence) # 토큰화
        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_test.append(temp_X)
    
    global words
    words = np.concatenate(X_train).tolist() # 
    counter = Counter(words)
    counter = counter.most_common(10000-4)
    vocab = ['', '', '', ''] + [key for key, _ in counter]
    word_to_index = {word:index for index, word in enumerate(vocab)}
        
    def wordlist_to_indexlist(wordlist):
        return [word_to_index[word] if word in word_to_index else word_to_index[''] for word in wordlist]
        
    X_train = list(map(wordlist_to_indexlist, X_train))
    X_test = list(map(wordlist_to_indexlist, X_test))
        
    return X_train, np.array(list(train_data['label'])), X_test, np.array(list(test_data['label'])), word_to_index
 
X_train, y_train, X_test, y_test, word_to_index = load_data(train_data, test_data)

# %%
print(type(temp_X))
print(temp_X) # 총 146182 개의temp_X가 X_train에 저장
# Out:
# <class 'list'>
# ['마무리', '또', '왜', '이래']

# %%
print(type(X_train))
print(len(X_train))
# Out:
# <class 'list'>
# 146182

# %%
words # X_train의 "문장"들을 words의 "단어" 리스트 형태로 반환
# Out:
# ['아',
#  '더',
#  '빙',
#  '.',
#  '.',
#  '진짜',
#  '짜증',
#  '나',
#  '네요',
#  '목소리',
#  '흠',
#  '.',
#  '..',
#  '포스터',
#  '보고',
#  '초딩',
#  '영화',
#  '줄',
#  '.',
#  '...',
#  '오버',
#  '연기',
#  '조차',
#  '가볍',
#  '지',
#  '않',
#  '구나',
#  '너무',
#  '재',
#  '밓었다그래서보는것을추천한다',
#  '교도소',
#  '이야기',
#  '구먼',
#  '.',
#  '.',
#  '솔직히',
#  '재미',
#  '없',
#  '다',
#  '.',
#  '.',
#  '평점',
#  '조정',
#  '사이몬페그',
#  '익살',
#  '스런',
#  '연기',
#  '돋보였',
#  '던',
#  '영화',
#  '!',
#  '스파이더맨',
#  '에서',
#  '늙',
#  '어',
#  '보이',
#  '기',
#  '만',
#  '했',
#  '던',
#  '커스틴',
#  '던스트',
#  '너무나',
#  '이뻐',
#  '보였',
#  '다',
#  '막',
#  '걸음마',
#  '뗀',
#  '3',
#  '세',
#  '부터',
#  '초등',
#  '학교',
#  '1',
#  '학년',
#  '생',
#  '인',
#  '8',
#  '살',
#  '용',
#  '영화',
#  '.',
#  'ㅋㅋㅋ',
#  '.',
#  '..',
#  '별반',
#  '개',
#  '아까움',
#  '.',
#  '원작',
#  '긴장감',
#  '을',
#  '제대로',
#  '살려',
#  '내',
#  '지',
#  '못했',
#  '다',
#  '.',
#  '별',
#  '반개',
#  '아깝',
#  '다',
#  '욕',
#  '나온다',
#  '이응경',
#  '길용우',
#  '연기',
#  '생활',
#  '몇',
#  '년',
# ...

# %%
print(type(words))
print(len(words))
# Out:
# <class 'list'>
# 2336238

# %%
index_to_word = {index:word for word, index in word_to_index.items()}
index_to_word
# Out:
# {3: '',
#  4: '.',
#  5: '영화',
#  6: '다',
#  7: '고',
#  8: '하',
#  9: '을',
#  10: '보',
#  11: '..',
#  12: '게',
#  13: ',',
#  14: '!',
#  15: '지',
#  16: '있',
#  17: '없',
#  18: '?',
#  19: '좋',
#  20: '나',
#  21: '었',
#  22: '만',
#  23: '는데',
#  24: '너무',
#  25: '봤',
#  26: '적',
#  27: '안',
#  28: '정말',
#  29: '로',
#  30: '음',
#  31: '것',
#  32: '아',
#  33: '네요',
#  34: '재밌',
#  35: '어',
#  36: '같',
#  37: '점',
#  38: '지만',
#  39: '진짜',
#  40: '했',
#  41: '에서',
#  42: '기',
#  43: '네',
#  44: '않',
#  45: '거',
#  46: '았',
#  47: '수',
#  48: '되',
#  49: '면',
#  50: 'ㅋㅋ',
#  51: '말',
#  52: '연기',
#  53: '인',
#  54: '주',
#  55: '내',
#  56: '최고',
#  57: '~',
#  58: '평점',
#  59: '이런',
#  60: '던',
#  61: '어요',
#  62: '할',
#  63: '왜',
#  64: '겠',
#  65: '1',
#  66: '스토리',
#  67: '해',
#  68: '습니다',
#  69: 'ㅋㅋㅋ',
#  70: '...',
#  71: '드라마',
#  72: '생각',
#  73: '아니',
#  74: '더',
#  75: '그',
#  76: '싶',
#  77: '사람',
#  78: '듯',
#  79: '때',
#  80: '감동',
#  81: '함',
#  82: '배우',
#  83: '본',
# ...

# %%
word_to_index
# Out:
# {'': 3,
#  '.': 4,
#  '영화': 5,
#  '다': 6,
#  '고': 7,
#  '하': 8,
#  '을': 9,
#  '보': 10,
#  '..': 11,
#  '게': 12,
#  ',': 13,
#  '!': 14,
#  '지': 15,
#  '있': 16,
#  '없': 17,
#  '?': 18,
#  '좋': 19,
#  '나': 20,
#  '었': 21,
#  '만': 22,
#  '는데': 23,
#  '너무': 24,
#  '봤': 25,
#  '적': 26,
#  '안': 27,
#  '정말': 28,
#  '로': 29,
#  '음': 30,
#  '것': 31,
#  '아': 32,
#  '네요': 33,
#  '재밌': 34,
#  '어': 35,
#  '같': 36,
#  '점': 37,
#  '지만': 38,
#  '진짜': 39,
#  '했': 40,
#  '에서': 41,
#  '기': 42,
#  '네': 43,
#  '않': 44,
#  '거': 45,
#  '았': 46,
#  '수': 47,
#  '되': 48,
#  '면': 49,
#  'ㅋㅋ': 50,
#  '말': 51,
#  '연기': 52,
#  '인': 53,
#  '주': 54,
#  '내': 55,
#  '최고': 56,
#  '~': 57,
#  '평점': 58,
#  '이런': 59,
#  '던': 60,
#  '어요': 61,
#  '할': 62,
#  '왜': 63,
#  '겠': 64,
#  '1': 65,
#  '스토리': 66,
#  '해': 67,
#  '습니다': 68,
#  'ㅋㅋㅋ': 69,
#  '...': 70,
#  '드라마': 71,
#  '생각': 72,
#  '아니': 73,
#  '더': 74,
#  '그': 75,
#  '싶': 76,
#  '사람': 77,
#  '듯': 78,
#  '때': 79,
#  '감동': 80,
#  '함': 81,
#  '배우': 82,
#  '본': 83,
# ...

# %%
len(word_to_index) #counter = counter.most_common(10000-4)
# Out:
# 9997

# %% [markdown]
# ### encoder & decoder

# %%
# 문장 1개를 활용할 딕셔너리와 함께 주면, 단어 인덱스 리스트 벡터로 변환해 주는 함수입니다. 
# 단, 모든 문장은 <BOS>로 시작하는 것으로 합니다. 
def get_encoded_sentence(sentence, word_to_index):
    return [word_to_index['<BOS>']]+[word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in sentence.split()]

# 여러 개의 문장 리스트를 한꺼번에 단어 인덱스 리스트 벡터로 encode해 주는 함수입니다. 
def get_encoded_sentences(sentences, word_to_index):
    return [get_encoded_sentence(sentence, word_to_index) for sentence in sentences]

# 숫자 벡터로 encode된 문장을 원래대로 decode하는 함수입니다. 
def get_decoded_sentence(encoded_sentence, index_to_word):
    return ' '.join(index_to_word[index] if index in index_to_word else '<UNK>' for index in encoded_sentence[1:])  #[1:]를 통해 <BOS>를 제외

# 여러 개의 숫자 벡터로 encode된 문장을 한꺼번에 원래대로 decode하는 함수입니다. 
def get_decoded_sentences(encoded_sentences, index_to_word):
    return [get_decoded_sentence(encoded_sentence, index_to_word) for encoded_sentence in encoded_sentences]

# %%
# 데이터셋 내 문장 길이 분포
total_data_text = list(X_train) + list(X_test)

num_tokens = [len(tokens) for tokens in total_data_text]
num_tokens = np.array(num_tokens)

print('문장길이 평균 : ', np.mean(num_tokens))
print('문장길이 최대 : ', np.max(num_tokens))
print('문장길이 표준편차 : ', np.std(num_tokens))
# Out:
# 문장길이 평균 :  15.96940191154864
# 문장길이 최대 :  116
# 문장길이 표준편차 :  12.843571191092

# %%
# 적절한 최대 문장 길이 지정
max_tokens = np.mean(num_tokens) + 2.5 * np.std(num_tokens)
maxlen = int(max_tokens)
print('pad_sequences maxlen : ', maxlen)
print('전체 문장의 {}%가 maxlen 설정값 이내에 포함됩니다. '.format(np.sum(num_tokens < max_tokens) / len(num_tokens)))
# Out:
# pad_sequences maxlen :  48
# 전체 문장의 0.9548784420929768%가 maxlen 설정값 이내에 포함됩니다.

# %% [markdown]
# ### pad_sequences를 통해 문장의 길이를 통일

# %%
# keras.preprocessing.sequence.pad_sequences 을 활용한 패딩 추가
# RNN의 경우 마지막입력이 무의미한 padding으로 채워지므로 비효율적
X_train = keras.preprocessing.sequence.pad_sequences(X_train,
                                                        value=word_to_index[""],
                                                        padding='pre',
                                                        maxlen=maxlen)

X_test = keras.preprocessing.sequence.pad_sequences(X_test,
                                                       value=word_to_index[""],
                                                       padding='pre',
                                                       maxlen=maxlen)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (146182, 48)
# (49157, 48)

# %% [markdown]
# ### validation set 구성

# %%
# validation set 30000건 분리
x_val = X_train[:30000]   
y_val = y_train[:30000]

# validation set을 제외한 나머지
partial_x_train = X_train[30000:]  
partial_y_train = y_train[30000:]

# %%
print(x_val.shape)
print(y_val.shape)
print(partial_x_train.shape)
print(partial_y_train.shape)
# Out:
# (30000, 48)
# (30000,)
# (116182, 48)
# (116182,)

# %% [markdown]
# # Apply to models

# %% [markdown]
# ##  LSTM 모델설계

# %%
vocab_size = 10000
word_vector_dim = 128

LSTM_ = keras.Sequential()
LSTM_.add(keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
LSTM_.add(keras.layers.LSTM(128))
LSTM_.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
LSTM_.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 128)         1280000
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# ...
# Total params: 1,411,713
# Trainable params: 1,411,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### LSTM 학습

# %%
LSTM_.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#Callback은 모델 학습 중 호출할 수 있는 기능
early = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
'''metric에 개선이 없을 때, 학습을 중단할 수 있는 콜백'''
# val_loss가 5번이상 나아지지 않으면 훈련을 종료

check = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_bast_only=True)
'''Keras 모델, 혹은 모델 가중치를 일정 빈도에 따라 저장하는 콜백'''
# 매 epoch마다 결과가 saving model to best_model.h5와 같이 저장
# Out:
# 'Keras 모델, 혹은 모델 가중치를 일정 빈도에 따라 저장하는 콜백'

# %%
LSTM_history = LSTM_.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    callbacks=[early, check],
                    batch_size=32,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/20
# 3631/3631 [==============================] - 25s 6ms/step - loss: 0.3710 - accuracy: 0.8359 - val_loss: 0.3226 - val_accuracy: 0.8607
#
# Epoch 00001: saving model to best_model.h5
# Epoch 2/20
# 3631/3631 [==============================] - 21s 6ms/step - loss: 0.2858 - accuracy: 0.8802 - val_loss: 0.3111 - val_accuracy: 0.8670
#
# Epoch 00002: saving model to best_model.h5
# Epoch 3/20
# 3631/3631 [==============================] - 21s 6ms/step - loss: 0.2419 - accuracy: 0.9006 - val_loss: 0.3279 - val_accuracy: 0.8650
#
# Epoch 00003: saving model to best_model.h5
# Epoch 4/20
# 3631/3631 [==============================] - 21s 6ms/step - loss: 0.2029 - accuracy: 0.9178 - val_loss: 0.3479 - val_accuracy: 0.8648
#
# Epoch 00004: saving model to best_model.h5
# Epoch 5/20
# 3631/3631 [==============================] - 21s 6ms/step - loss: 0.1660 - accuracy: 0.9340 - val_loss: 0.4047 - val_accuracy: 0.8582
#
# Epoch 00005: saving model to best_model.h5
# Epoch 6/20
# ...

# %%
LSTM_history.history
# Out:
# {'loss': [0.37095433473587036,
#   0.28584495186805725,
#   0.2419034242630005,
#   0.20289218425750732,
#   0.16599199175834656,
#   0.13214416801929474,
#   0.10585832595825195],
#  'accuracy': [0.8359040021896362,
#   0.8802310228347778,
#   0.900604248046875,
#   0.917775571346283,
#   0.9340087175369263,
#   0.9489938020706177,
#   0.9589437246322632],
#  'val_loss': [0.3225919008255005,
#   0.3110513687133789,
#   0.32787495851516724,
#   0.3478785753250122,
#   0.40467873215675354,
#   0.46685266494750977,
#   0.5284296870231628],
#  'val_accuracy': [0.8607000112533569,
#   0.8670333623886108,
#   0.8649666905403137,
#   0.8647666573524475,
#   0.8582333326339722,
#   0.8517333269119263,
#   0.853766679763794]}

# %% [markdown]
# ### 네이버 영화리뷰 데이터 감성분석 정확도

# %%
loaded_model = load_model('best_model.h5')
results = loaded_model.evaluate(X_test,  y_test, verbose=2)

print(results)
# Out:
# 1537/1537 - 4s - loss: 0.5301 - accuracy: 0.8525
# [0.5301176905632019, 0.8524726629257202]

# %% [markdown]
# ### 시각화

# %%
LSTM_history_dict = LSTM_history.history

acc = LSTM_history_dict['accuracy']
val_acc = LSTM_history_dict['val_accuracy']
loss = LSTM_history_dict['loss']
val_loss = LSTM_history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss-LSTM_')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy-LSTM_')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ### Embedding layer 분석
# - model의 첫 번째 레이어는 바로 Embedding 레이어였습니다. 이 레이어는 우리가 가진 사전의 단어 개수 X 워드 벡터 사이즈만큼의 크기를 가진 학습 파라미터였습니다. 만약 우리의 감성 분류 모델이 학습이 잘 되었다면, Embedding 레이어에 학습된 우리의 워드 벡터들도 의미 공간상에 유의미한 형태로 학습되었을 것입니다. 확인해 보겠습니다

# %%
LSTM_.layers

# %%
LSTM_.layers[0]

# %%
embedding_layer = LSTM_.layers[0]
weights = embedding_layer.get_weights()[0]
print(weights.shape)
# Out:
# (10000, 128)

# %%
# 학습한 Embedding 파라미터를 파일에 써서 저장합니다

word2vec_file_path = os.getenv('HOME')+'/aiffel/sentiment_classification/LSTMword2vec.txt'
f = open(word2vec_file_path, 'w')
f.write('{} {}\n'.format(vocab_size-4, word_vector_dim))

vectors = LSTM_.get_weights()[0]
for i in range(4,vocab_size):
    f.write('{} {}\n'.format(index_to_word[i], ' '.join(map(str, list(vectors[i, :])))))
f.close()

# %%
# gensim에서 제공하는 패키지를 이용해, 위에 남긴 임베딩 파라미터를 읽어서 word vector로 활용

word_vectors = Word2VecKeyedVectors.load_word2vec_format(word2vec_file_path, binary=False)
vector = word_vectors['노래']
vector
# Out:
# array([ 0.06977775, -0.0867358 , -0.11455726,  0.12211177,  0.17432041,
#        -0.12272346, -0.09785817, -0.1667483 , -0.00568878, -0.05221548,
#         0.15450193,  0.14417987,  0.20973241, -0.07866935, -0.07570682,
#         0.05258527,  0.07388081,  0.26317075, -0.04883301,  0.05693079,
#         0.00240636,  0.01686291, -0.18399233, -0.0858442 ,  0.09675748,
#         0.1884857 ,  0.07906201,  0.08721004, -0.01609832, -0.15792038,
#        -0.10527528,  0.11441475, -0.00242597, -0.02926303,  0.23631775,
#         0.0353749 , -0.00518838,  0.12105124,  0.13822767, -0.04682467,
#        -0.10645573,  0.18340015,  0.15909293, -0.13798773,  0.07719248,
#         0.2073898 , -0.09818936, -0.0195809 , -0.02479418,  0.13864847,
#        -0.0753179 , -0.0245394 ,  0.11222015, -0.23099494,  0.01978432,
#        -0.06560757, -0.03916529,  0.05849497, -0.05200009, -0.06007167,
#         0.07806811, -0.041809  ,  0.04191074,  0.03576918, -0.2692937 ,
# ...

# %%
word_vectors.similar_by_word("쵝오")
# Out:
# [('예쁨', 0.8802985548973083),
#  ('슬퍼요', 0.8760294318199158),
#  ('멋져', 0.873477041721344),
#  ('진진', 0.8720799088478088),
#  ('탁월', 0.8691685795783997),
#  ('조아', 0.8681344985961914),
#  ('미남', 0.8679569363594055),
#  ('그리움', 0.8668029308319092),
#  ('뿌듯', 0.8660972118377686),
#  ('앓', 0.865734338760376)]

# %% [markdown]
# ## 한국어 Word2Vec 임베딩 활용하여 성능 개선

# %%
word2vec_path = os.getenv('HOME')+'/data/word2vec_ko.model'
word2vec = gensim.models.Word2Vec.load(word2vec_path)
vector = word2vec.wv['컴퓨터']
vector
# Out:
# array([-0.35898918, -3.7382367 , -1.1435223 , -0.2520832 , -2.421575  ,
#         1.675243  ,  0.12040154,  0.30027202, -0.10066335, -1.852855  ,
#        -1.5231812 ,  4.249661  , -2.0461752 , -1.8994397 ,  1.9720789 ,
#         2.2885437 ,  0.37752038, -0.37131143,  1.5192999 , -3.986562  ,
#         1.5290304 , -1.1876138 , -4.3212905 ,  0.60457045, -0.1556344 ,
#        -0.8781025 ,  3.1387296 , -0.5732489 ,  2.6950948 ,  2.43627   ,
#        -1.803436  ,  1.191884  , -1.9603088 ,  1.97387   , -0.05861414,
#        -1.2503568 ,  1.649908  , -1.9944221 , -0.04815336, -0.45580134,
#         2.1869504 , -3.3291643 ,  1.1504062 ,  0.96880984, -1.1941013 ,
#         2.685823  ,  1.5262356 ,  0.13755637,  3.1111014 ,  0.23526062,
#         0.36584985,  0.36928275, -0.5305036 , -3.5831432 ,  2.6298168 ,
#        -0.65791756,  4.177953  , -2.858328  , -0.22881825,  0.34941065,
#         0.12948069,  5.346858  ,  2.2717035 ,  0.06239161,  0.01912611,
# ...

# %%
word2vec.wv['노래']
# Out:
# array([ 0.31157956, -1.9104943 , -2.310177  , -1.9809129 ,  1.0712352 ,
#         0.41321734, -0.0429831 , -1.5197281 , -4.4229865 ,  0.8348897 ,
#        -1.5512861 , -0.94695616, -3.791187  , -5.211677  ,  2.2611725 ,
#         1.309436  , -1.1452844 ,  1.4273468 ,  3.390127  , -3.4698644 ,
#        -1.2812951 ,  3.0490654 ,  0.2055517 , -1.8042544 ,  1.3913008 ,
#         0.24131915, -1.8496529 ,  1.9416335 , -3.0497866 , -4.51937   ,
#        -4.7339625 ,  3.5791383 , -2.0757716 ,  0.5013038 , -0.22226945,
#         2.0505848 , -2.6811044 ,  0.8876423 ,  0.32847577,  1.669949  ,
#         3.4434319 , -2.8450842 ,  2.489771  ,  1.820732  ,  1.2205088 ,
#         3.0693545 ,  4.0694256 ,  0.40085015,  0.09539098, -1.6477063 ,
#        -0.7693934 , -3.7467911 ,  1.5443817 , -1.9020754 , -3.3540792 ,
#        -2.671685  ,  2.2225385 , -3.1336513 ,  2.2620757 ,  1.7185363 ,
#        -0.5385146 , -0.5127335 , -1.2981753 , -6.5714107 ,  0.44654113,
# ...

# %%
word_vectors.similar_by_word("학교")
# Out:
# [('쥬', 0.6694825887680054),
#  ('겨울', 0.6684058308601379),
#  ('여러', 0.6657171845436096),
#  ('우연히', 0.6624504923820496),
#  ('이어지', 0.6516105532646179),
#  ('러닝', 0.6416823863983154),
#  ('홍금보', 0.6377439498901367),
#  ('발랄', 0.631523847579956),
#  ('그렇지만', 0.62771075963974),
#  ('칭찬', 0.6208696961402893)]

# %%
word2vec

# %% [markdown]
# ### 전 모델의 임베딩 레이어를 Word2Vec(word_vectors)의 것으로 교체하여 설계

# %%
vocab_size = 10000
word_vector_dim = 128 # max dim is 128

embedding_matrix = np.random.rand(vocab_size, word_vector_dim)

# embedding_matrix에 Word2Vec 워드 벡터를 단어 하나씩마다 차례차례 카피한다.
for i in range(4,vocab_size):
    if index_to_word[i] in word_vectors : #instead of 'word2vec' / 'word2vec' is not literable
        embedding_matrix[i] = word_vectors[index_to_word[i]]

# %%
type(word2vec)
# Out:
# gensim.models.word2vec.Word2Vec

# %%
vocab_size = 10000
word_vector_dim = 128

LSTM_ko = keras.Sequential()
LSTM_ko.add(keras.layers.Embedding(vocab_size, 
                                 word_vector_dim, 
                                 embeddings_initializer=Constant(embedding_matrix),
                                 input_length=maxlen, 
                                 trainable=True))
LSTM_ko.add(keras.layers.LSTM(64))
LSTM_ko.add(keras.layers.Dense(256, activation='relu'))
LSTM_ko.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
LSTM_ko.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 48, 128)           1280000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# ...
# Total params: 1,346,305
# Trainable params: 1,346,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Word2Vec학습

# %%
LSTM_ko.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
ealry_ko = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
check_ko = ModelCheckpoint('best_model_ko.h5', monitor='val_acc', mode='max', verbose=1, save_bast_only=True)

# %%
LSTM_ko_history = LSTM_ko.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    callbacks=[ealry_ko, check_ko],
                    batch_size=32,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/20
# 3631/3631 [==============================] - 22s 6ms/step - loss: 0.2115 - accuracy: 0.9134 - val_loss: 0.4305 - val_accuracy: 0.8593
#
# Epoch 00001: saving model to best_model_ko.h5
# Epoch 2/20
# 3631/3631 [==============================] - 20s 6ms/step - loss: 0.1328 - accuracy: 0.9477 - val_loss: 0.4457 - val_accuracy: 0.8462
#
# Epoch 00002: saving model to best_model_ko.h5
# Epoch 3/20
# 3631/3631 [==============================] - 20s 5ms/step - loss: 0.1038 - accuracy: 0.9595 - val_loss: 0.6025 - val_accuracy: 0.8525
#
# Epoch 00003: saving model to best_model_ko.h5
# Epoch 4/20
# 3631/3631 [==============================] - 20s 6ms/step - loss: 0.0828 - accuracy: 0.9682 - val_loss: 0.6340 - val_accuracy: 0.8480
#
# Epoch 00004: saving model to best_model_ko.h5
# Epoch 5/20
# 3631/3631 [==============================] - 20s 5ms/step - loss: 0.0704 - accuracy: 0.9730 - val_loss: 0.7036 - val_accuracy: 0.8428
#
# Epoch 00005: saving model to best_model_ko.h5
# ...

# %% [markdown]
# ### Word2Vec(word_vectors) 정확도

# %%
loaded_model = load_model('best_model_ko.h5')
results = loaded_model.evaluate(X_test,  y_test, verbose=2)

print(results)
# Out:
# 1537/1537 - 4s - loss: 0.7166 - accuracy: 0.8414
# [0.7166322469711304, 0.8414468169212341]

# %% [markdown]
# ### Word2Vec(word_vectors) 시각화

# %%
LSTM_ko_history_dict = LSTM_ko_history.history

acc_ko = LSTM_ko_history_dict['accuracy']
val_acc_ko = LSTM_ko_history_dict['val_accuracy']
loss_ko = LSTM_ko_history_dict['loss']
val_loss_ko = LSTM_ko_history_dict['val_loss']

epochs = range(1, len(acc_ko) + 1)

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.plot(epochs, loss_ko, 'bo', label='Training loss')
plt.plot(epochs, val_loss_ko, 'b', label='Validation loss')
plt.title('Training and validation loss-LSTM_ko')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, acc_ko, 'bo', label='Training acc')
plt.plot(epochs, val_acc_ko, 'b', label='Validation acc')
plt.title('Training and validation accuracy-LSTM_ko')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## GlobalMaxPooling

# %% [markdown]
# ### GMP설계

# %%
vocab_size = 10000
word_vector_dim = 64

GMP_model = keras.Sequential()
GMP_model.add(keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
GMP_model.add(keras.layers.GlobalMaxPooling1D())
GMP_model.add(keras.layers.Dense(8, activation='relu'))
GMP_model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
GMP_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, None, 64)          640000
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# ...
# Total params: 640,529
# Trainable params: 640,529
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GMP학습

# %%
GMP_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
GMP_history = GMP_model.fit(partial_x_train,
                    partial_y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.3939 - accuracy: 0.8258 - val_loss: 0.3420 - val_accuracy: 0.8499
# Epoch 2/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.3029 - accuracy: 0.8736 - val_loss: 0.3410 - val_accuracy: 0.8541
# Epoch 3/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.2602 - accuracy: 0.8940 - val_loss: 0.3520 - val_accuracy: 0.8510
# Epoch 4/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.2241 - accuracy: 0.9125 - val_loss: 0.3666 - val_accuracy: 0.8506
# Epoch 5/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.1911 - accuracy: 0.9265 - val_loss: 0.4011 - val_accuracy: 0.8454
# Epoch 6/10
# 3631/3631 [==============================] - 12s 3ms/step - loss: 0.1628 - accuracy: 0.9398 - val_loss: 0.4354 - val_accuracy: 0.8440
# Epoch 7/10
# ...

# %% [markdown]
# ### GMP정확도

# %%
results = GMP_model.evaluate(X_test,  y_test, verbose=2)
print(results)
# Out:
# 1537/1537 - 2s - loss: 0.6418 - accuracy: 0.8285
# [0.6417995095252991, 0.8285086750984192]

# %%
GMP_history_dict = GMP_history.history

# %% [markdown]
# ### GMP시각화

# %%
acc_g = GMP_history_dict['accuracy']
val_acc_g = GMP_history_dict['val_accuracy']
loss_g = GMP_history_dict['loss']
val_loss_g = GMP_history_dict['val_loss']

epochs = range(1, len(acc_g) + 1)

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.plot(epochs, loss_g, 'bo', label='Training loss')
plt.plot(epochs, val_loss_g, 'b', label='Validation loss')
plt.title('Training and validation loss-GlobalMaxPooling')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, acc_g, 'bo', label='Training acc')
plt.plot(epochs, val_acc_g, 'b', label='Validation acc')
plt.title('Training and validation accuracy-GlobalMaxPooling')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# # 회고
#
#
#         - LSTM, Word2vec, GMP모델로 학습
#         - LSTM의 정확도: 85%
#         - Epochs 7에서  val_loss가 5번이상 나아지지 않아 훈련을 종료,
#           더이상의 반복 학습은 의미가 없는 것으로 보이며,
#           val_acc 의 경우 Epochs 1~3구간에서 가장 높게나왔으며 그 이후에는 낮아짐.
#         - 한국어 word2vec의 경우 개선될 것으로 기대했으나 큰 변화가 없었으며 정확도는 1% 정도 낮아짐
#         - LSTM의 Training set의 정확도는 높은 반면 val_acc는 상대적으로 낮아진 것으로봐서
#           overfitting이 발생된 것으로 보임.
#         - ref. link(keras.callbacks)
#             -https://keras.io/ko/callbacks/

# %%
import cv2

img_path1= os.getenv('HOME')+'/aiffel/sentiment_classification/data/LSTM_.png'  
img_path2 = os.getenv('HOME')+'/aiffel/sentiment_classification/data/LSTM_ko.png'
img_path3 = os.getenv('HOME')+'/aiffel/sentiment_classification/data/GMP.png'

img_orig1 = cv2.imread(img_path1) 
img_orig2= cv2.imread(img_path2) 
img_orig3= cv2.imread(img_path3) 

titles = ['LSTM_', 'LSTM_ko', 'GMP']
images = [img_orig1, img_orig2, img_orig3]


for i in range(3):
    plt.figure(figsize=(10, 5))
    plt.imshow(images[i])
    plt.title(titles[i])
